# %%
import torch
from torch import nn
from torch import optim
from torch.nn import functional

# %%
x=torch.randn(10,3,100)

# %% [markdown]
# RNN num_layers=1

# %%
rnn=nn.RNN(input_size=100,hidden_size=20,num_layers=1)
print(rnn)

x=torch.randn(10,3,100)
out,h=rnn(x,torch.zeros(1,3,20))
print(out.shape,h.shape)
print(vars(rnn))
# Out:
# RNN(100, 20)
# torch.Size([10, 3, 20]) torch.Size([1, 3, 20])
# {'nonlinearity': 'tanh', 'training': True, '_parameters': OrderedDict([('weight_ih_l0', Parameter containing:
# tensor([[-0.0581, -0.0189,  0.1635,  ..., -0.0260, -0.1575,  0.1361],
#         [ 0.0254, -0.1955,  0.0371,  ..., -0.0047, -0.0010,  0.1847],
#         [-0.1634,  0.1206, -0.0846,  ..., -0.0537,  0.1000,  0.1245],
#         ...,
#         [-0.0099, -0.1410,  0.1241,  ..., -0.1873,  0.2055,  0.1868],
#         [-0.0354, -0.0451, -0.1053,  ..., -0.1429,  0.0244, -0.1478],
#         [-0.1009, -0.0937,  0.0902,  ...,  0.0996, -0.2167, -0.1550]],
#        requires_grad=True)), ('weight_hh_l0', Parameter containing:
# tensor([[ 0.2042,  0.0103,  0.1075, -0.1497,  0.0620,  0.0619, -0.1340,  0.0792,
#          -0.1330,  0.1254,  0.0059, -0.0526,  0.1879, -0.0952, -0.0436,  0.1605,
#           0.1268,  0.1463,  0.2049,  0.0769],
#         [ 0.1203, -0.0044,  0.0689, -0.1251,  0.1015,  0.0822, -0.0291, -0.0870,
#           0.1190,  0.0561, -0.1114, -0.0839, -0.1739,  0.1606,  0.0051,  0.1105,
#          -0.0130,  0.0610,  0.0692,  0.0146],
#         [ 0.1764,  0.1889, -0.1206, -0.1328, -0.0659, -0.0843,  0.0019, -0.1041,
#           0.2198, -0.0381, -0.1458, -0.0775,  0.0462, -0.0416, -0.1614, -0.2171,
#          -0.1372,  0.1629,  0.0474, -0.2004],
#         [-0.1797,  0.0591, -0.1779,  0.0854, -0.1295, -0.0797, -0.1774,  0.1760,
#          -0.1043,  0.0789,  0.1019,  0.1583,  0.0154, -0.1022,  0.1158,  0.1568,
#           0.0253, -0.0027,  0.0385,  0.0383],
#         [-0.0728,  0.0809,  0.0320, -0.1949,  0.0479,  0.0243,  0.0524,  0.0057,
#          -0.1005,  0.1198,  0.0070, -0.1796, -0.0413, -0.1365,  0.0134, -0.1997,
#          -0.1930,  0.1350,  0.1419,  0.1300],
#         [-0.0364,  0.0370,  0.1125, -0.1365,  0.0893,  0.1884,  0.0500,  0.0419,
#           0.1946,  0.1970,  0.1037,  0.1885,  0.0446,  0.1065, -0.1051, -0.1440,
#          -0.1893,  0.1518, -0.0355, -0.1576],
#         [ 0.0540, -0.2164,  0.1899, -0.1315,  0.0517, -0.1227, -0.1563,  0.0873,
#           0.0016, -0.1309,  0.0334, -0.0387, -0.1315,  0.0541, -0.0928,  0.1785,
#          -0.0369,  0.0816,  0.1694,  0.0947],
#         [-0.0580,  0.0045,  0.1297, -0.0450, -0.0056,  0.1281,  0.0603,  0.0426,
#          -0.2120, -0.1310, -0.0302, -0.0299,  0.0544, -0.1600, -0.1629, -0.1674,
#          -0.0135, -0.0876, -0.0218,  0.1072],
#         [ 0.1981, -0.1856,  0.1380,  0.1239, -0.0014, -0.1469, -0.1382,  0.1648,
#           0.1397, -0.0079, -0.0494, -0.0415, -0.0451, -0.1194, -0.1751, -0.0504,
#           0.0966,  0.1495,  0.2009,  0.0083],
#         [ 0.2142,  0.1797,  0.2107,  0.2213,  0.0328,  0.0650, -0.1495, -0.1120,
#          -0.0248, -0.1315, -0.1855,  0.1494, -0.0273,  0.2179, -0.0060, -0.1689,
#          -0.1480, -0.0257, -0.1931, -0.2016],
#         [ 0.2156, -0.1324, -0.0656, -0.0272, -0.0394, -0.1917, -0.1048, -0.0329,
#          -0.1825,  0.2004,  0.1650,  0.1074,  0.1568,  0.0719,  0.1601,  0.1038,
#          -0.0035, -0.1220,  0.0359,  0.1525],
#         [-0.1001,  0.2169, -0.2044, -0.0018, -0.1575, -0.1120, -0.2176, -0.0891,
#          -0.1917, -0.2214, -0.1852,  0.0596, -0.1541,  0.0915, -0.2051,  0.0883,
#          -0.0880,  0.1585,  0.0965, -0.0114],
#         [-0.0762,  0.1624,  0.1050, -0.1511, -0.1293,  0.1074,  0.1963,  0.0664,
#           0.0798, -0.0154,  0.0788,  0.1900,  0.0359,  0.1821, -0.1452, -0.1355,
#           0.2146,  0.1651,  0.1365,  0.0617],
#         [ 0.2163, -0.0366, -0.0341,  0.1840,  0.1363,  0.1103, -0.2056,  0.1448,
#          -0.1711,  0.1013,  0.1229,  0.0154,  0.0382,  0.0418, -0.0927,  0.1872,
#          -0.2046,  0.0551, -0.1403,  0.1609],
#         [ 0.1696, -0.1201,  0.1200,  0.1310,  0.2065,  0.0051,  0.1843,  0.1216,
#          -0.2153,  0.0919, -0.0580,  0.2066, -0.0968, -0.0701, -0.1733,  0.0534,
#           0.2070, -0.0073, -0.1212, -0.1396],
#         [-0.0494,  0.0813, -0.2227, -0.1354,  0.1237,  0.1609,  0.1425,  0.1288,
#          -0.1347,  0.1798, -0.0078,  0.1572, -0.0690, -0.0694,  0.0267,  0.1822,
#          -0.1322,  0.1734, -0.0797,  0.2080],
#         [-0.0811, -0.0033,  0.0956, -0.1139,  0.1904, -0.0014, -0.0122, -0.0152,
#           0.0944,  0.1546,  0.0397, -0.0367, -0.0125,  0.0808, -0.1581, -0.1288,
#          -0.1570, -0.0582, -0.2058,  0.1846],
#         [-0.0925,  0.0957,  0.1071, -0.0445,  0.1226,  0.0284,  0.0524, -0.0848,
#          -0.1497, -0.1244, -0.1784,  0.2208, -0.2213, -0.1595, -0.0720,  0.0021,
#           0.1338,  0.1184, -0.1693, -0.1192],
#         [ 0.0474,  0.0994,  0.0082,  0.0033, -0.2145, -0.0726, -0.0099, -0.2032,
#          -0.0149,  0.0921, -0.0452,  0.0364, -0.0574, -0.0551,  0.0471, -0.0127,
#           0.1420,  0.2210,  0.1340,  0.0628],
#         [-0.1358,  0.1167, -0.0495,  0.1467,  0.1907,  0.1917,  0.1647, -0.1302,
#          -0.1596,  0.1561,  0.0124,  0.2219,  0.1992, -0.0557, -0.0365, -0.0323,
#          -0.2027, -0.1673,  0.1851, -0.1342]], requires_grad=True)), ('bias_ih_l0', Parameter containing:
# tensor([-0.0858,  0.1111,  0.1795, -0.1622,  0.0584,  0.0098,  0.1851, -0.0636,
#         -0.0060, -0.1892, -0.1389, -0.0802,  0.0248,  0.0013, -0.0992,  0.1823,
#         -0.2030, -0.0621, -0.0436,  0.2164], requires_grad=True)), ('bias_hh_l0', Parameter containing:
# tensor([-0.1230,  0.1649, -0.0767, -0.0026,  0.1768, -0.1798, -0.0393, -0.1064,
#          0.0428,  0.0101,  0.0640, -0.0824,  0.0948, -0.0050,  0.1285, -0.0056,
#          0.1654,  0.2121, -0.0570,  0.1739], requires_grad=True))]), '_buffers': OrderedDict(), '_backward_hooks': OrderedDict(), '_forward_hooks': OrderedDict(), '_forward_pre_hooks': OrderedDict(), '_state_dict_hooks': OrderedDict(), '_load_state_dict_pre_hooks': OrderedDict(), '_modules': OrderedDict(), 'mode': 'RNN_TANH', 'input_size': 100, 'hidden_size': 20, 'num_layers': 1, 'bias': True, 'batch_first': False, 'dropout': 0.0, 'bidirectional': False, '_flat_weights_names': ['weight_ih_l0', 'weight_hh_l0', 'bias_ih_l0', 'bias_hh_l0'], '_all_weights': [['weight_ih_l0', 'weight_hh_l0', 'bias_ih_l0', 'bias_hh_l0']], '_flat_weights': [Parameter containing:
# tensor([[-0.0581, -0.0189,  0.1635,  ..., -0.0260, -0.1575,  0.1361],
#         [ 0.0254, -0.1955,  0.0371,  ..., -0.0047, -0.0010,  0.1847],
#         [-0.1634,  0.1206, -0.0846,  ..., -0.0537,  0.1000,  0.1245],
#         ...,
#         [-0.0099, -0.1410,  0.1241,  ..., -0.1873,  0.2055,  0.1868],
#         [-0.0354, -0.0451, -0.1053,  ..., -0.1429,  0.0244, -0.1478],
#         [-0.1009, -0.0937,  0.0902,  ...,  0.0996, -0.2167, -0.1550]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.2042,  0.0103,  0.1075, -0.1497,  0.0620,  0.0619, -0.1340,  0.0792,
#          -0.1330,  0.1254,  0.0059, -0.0526,  0.1879, -0.0952, -0.0436,  0.1605,
#           0.1268,  0.1463,  0.2049,  0.0769],
#         [ 0.1203, -0.0044,  0.0689, -0.1251,  0.1015,  0.0822, -0.0291, -0.0870,
#           0.1190,  0.0561, -0.1114, -0.0839, -0.1739,  0.1606,  0.0051,  0.1105,
#          -0.0130,  0.0610,  0.0692,  0.0146],
#         [ 0.1764,  0.1889, -0.1206, -0.1328, -0.0659, -0.0843,  0.0019, -0.1041,
#           0.2198, -0.0381, -0.1458, -0.0775,  0.0462, -0.0416, -0.1614, -0.2171,
#          -0.1372,  0.1629,  0.0474, -0.2004],
#         [-0.1797,  0.0591, -0.1779,  0.0854, -0.1295, -0.0797, -0.1774,  0.1760,
#          -0.1043,  0.0789,  0.1019,  0.1583,  0.0154, -0.1022,  0.1158,  0.1568,
#           0.0253, -0.0027,  0.0385,  0.0383],
#         [-0.0728,  0.0809,  0.0320, -0.1949,  0.0479,  0.0243,  0.0524,  0.0057,
#          -0.1005,  0.1198,  0.0070, -0.1796, -0.0413, -0.1365,  0.0134, -0.1997,
#          -0.1930,  0.1350,  0.1419,  0.1300],
#         [-0.0364,  0.0370,  0.1125, -0.1365,  0.0893,  0.1884,  0.0500,  0.0419,
#           0.1946,  0.1970,  0.1037,  0.1885,  0.0446,  0.1065, -0.1051, -0.1440,
#          -0.1893,  0.1518, -0.0355, -0.1576],
#         [ 0.0540, -0.2164,  0.1899, -0.1315,  0.0517, -0.1227, -0.1563,  0.0873,
#           0.0016, -0.1309,  0.0334, -0.0387, -0.1315,  0.0541, -0.0928,  0.1785,
#          -0.0369,  0.0816,  0.1694,  0.0947],
#         [-0.0580,  0.0045,  0.1297, -0.0450, -0.0056,  0.1281,  0.0603,  0.0426,
#          -0.2120, -0.1310, -0.0302, -0.0299,  0.0544, -0.1600, -0.1629, -0.1674,
#          -0.0135, -0.0876, -0.0218,  0.1072],
#         [ 0.1981, -0.1856,  0.1380,  0.1239, -0.0014, -0.1469, -0.1382,  0.1648,
#           0.1397, -0.0079, -0.0494, -0.0415, -0.0451, -0.1194, -0.1751, -0.0504,
#           0.0966,  0.1495,  0.2009,  0.0083],
#         [ 0.2142,  0.1797,  0.2107,  0.2213,  0.0328,  0.0650, -0.1495, -0.1120,
#          -0.0248, -0.1315, -0.1855,  0.1494, -0.0273,  0.2179, -0.0060, -0.1689,
#          -0.1480, -0.0257, -0.1931, -0.2016],
#         [ 0.2156, -0.1324, -0.0656, -0.0272, -0.0394, -0.1917, -0.1048, -0.0329,
#          -0.1825,  0.2004,  0.1650,  0.1074,  0.1568,  0.0719,  0.1601,  0.1038,
#          -0.0035, -0.1220,  0.0359,  0.1525],
#         [-0.1001,  0.2169, -0.2044, -0.0018, -0.1575, -0.1120, -0.2176, -0.0891,
#          -0.1917, -0.2214, -0.1852,  0.0596, -0.1541,  0.0915, -0.2051,  0.0883,
#          -0.0880,  0.1585,  0.0965, -0.0114],
#         [-0.0762,  0.1624,  0.1050, -0.1511, -0.1293,  0.1074,  0.1963,  0.0664,
#           0.0798, -0.0154,  0.0788,  0.1900,  0.0359,  0.1821, -0.1452, -0.1355,
#           0.2146,  0.1651,  0.1365,  0.0617],
#         [ 0.2163, -0.0366, -0.0341,  0.1840,  0.1363,  0.1103, -0.2056,  0.1448,
#          -0.1711,  0.1013,  0.1229,  0.0154,  0.0382,  0.0418, -0.0927,  0.1872,
#          -0.2046,  0.0551, -0.1403,  0.1609],
#         [ 0.1696, -0.1201,  0.1200,  0.1310,  0.2065,  0.0051,  0.1843,  0.1216,
#          -0.2153,  0.0919, -0.0580,  0.2066, -0.0968, -0.0701, -0.1733,  0.0534,
#           0.2070, -0.0073, -0.1212, -0.1396],
#         [-0.0494,  0.0813, -0.2227, -0.1354,  0.1237,  0.1609,  0.1425,  0.1288,
#          -0.1347,  0.1798, -0.0078,  0.1572, -0.0690, -0.0694,  0.0267,  0.1822,
#          -0.1322,  0.1734, -0.0797,  0.2080],
#         [-0.0811, -0.0033,  0.0956, -0.1139,  0.1904, -0.0014, -0.0122, -0.0152,
#           0.0944,  0.1546,  0.0397, -0.0367, -0.0125,  0.0808, -0.1581, -0.1288,
#          -0.1570, -0.0582, -0.2058,  0.1846],
#         [-0.0925,  0.0957,  0.1071, -0.0445,  0.1226,  0.0284,  0.0524, -0.0848,
#          -0.1497, -0.1244, -0.1784,  0.2208, -0.2213, -0.1595, -0.0720,  0.0021,
#           0.1338,  0.1184, -0.1693, -0.1192],
#         [ 0.0474,  0.0994,  0.0082,  0.0033, -0.2145, -0.0726, -0.0099, -0.2032,
#          -0.0149,  0.0921, -0.0452,  0.0364, -0.0574, -0.0551,  0.0471, -0.0127,
#           0.1420,  0.2210,  0.1340,  0.0628],
#         [-0.1358,  0.1167, -0.0495,  0.1467,  0.1907,  0.1917,  0.1647, -0.1302,
#          -0.1596,  0.1561,  0.0124,  0.2219,  0.1992, -0.0557, -0.0365, -0.0323,
#          -0.2027, -0.1673,  0.1851, -0.1342]], requires_grad=True), Parameter containing:
# tensor([-0.0858,  0.1111,  0.1795, -0.1622,  0.0584,  0.0098,  0.1851, -0.0636,
#         -0.0060, -0.1892, -0.1389, -0.0802,  0.0248,  0.0013, -0.0992,  0.1823,
#         -0.2030, -0.0621, -0.0436,  0.2164], requires_grad=True), Parameter containing:
# tensor([-0.1230,  0.1649, -0.0767, -0.0026,  0.1768, -0.1798, -0.0393, -0.1064,
#          0.0428,  0.0101,  0.0640, -0.0824,  0.0948, -0.0050,  0.1285, -0.0056,
#          0.1654,  0.2121, -0.0570,  0.1739], requires_grad=True)]}

# %% [markdown]
# RNN num_layers=4

# %%
rnn=nn.RNN(input_size=100,hidden_size=20,num_layers=4)
print(rnn)

x=torch.randn(10,3,100)
out.h=rnn(x,torch.zeros(4,3,20))
print(out.shape,h.shape)
# print(vars(rnn))
# Out:
# RNN(100, 20, num_layers=4)
# torch.Size([10, 3, 20]) torch.Size([1, 3, 20])

# %% [markdown]
# RNNcell num_layers=1

# %%
cell=nn.RNNCell(100,20)
h=torch.zeros(3,20)
for x_t in x: 
    h=cell(x_t,h)
print(h.shape)
# Out:
# torch.Size([3, 20])

# %% [markdown]
# RNNcell num_layers=2

# %%
cell1=nn.RNNCell(100,30)
cell2=nn.RNNCell(30,20)
h1=torch.zeros(3,30)
h2=torch.zeros(3,20)

for x_t in x: 
    h1=cell1(x_t,h1)
    h2=cell2(h1,h2)
print(h2.shape)
# Out:
# torch.Size([3, 20])

# %% [markdown]
# LSTM

# %%
lstm=nn.LSTM(input_size=100,hidden_size=20,num_layers=4)
print(lstm)

out,(h,c)=lstm(x)
print(out.shape,h.shape,c.shape)
# Out:
# LSTM(100, 20, num_layers=4)
# torch.Size([10, 3, 20]) torch.Size([4, 3, 20]) torch.Size([4, 3, 20])

# %% [markdown]
# LSTMcell num_layers=1

# %%
cell=nn.LSTMCell(input_size=100,hidden_size=20)
h=torch.zeros(3,20)
c=torch.zeros(3,20)
for x_t in x: 
    h,c=cell(x_t,[h,c])
print(h.shape,c.shape)
# Out:
# torch.Size([3, 20]) torch.Size([3, 20])

# %% [markdown]
# LSTMcell num_layers=2

# %%
cell1 = nn.LSTMCell(input_size=100, hidden_size=30)
cell2 = nn.LSTMCell(input_size=30, hidden_size=20)
h1 = torch.zeros(3, 30)
c1 = torch.zeros(3, 30)
h2 = torch.zeros(3, 20)
c2 = torch.zeros(3, 20)
for xt in x:
    h1, c1 = cell1(xt, [h1, c1])
    h2, c2 = cell2(h1, [h2, c2])
print(h2.shape, c2.shape)
# Out:
# torch.Size([3, 20]) torch.Size([3, 20])
